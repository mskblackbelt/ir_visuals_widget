# %%
import anywidget
import traitlets

# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
class CounterWidget(anywidget.AnyWidget):
    _esm = "./index.js"
    _css = "./index.css"
    count = traitlets.Int(0).tag(sync=True)

w = CounterWidget(count=42)
w

# %%
w

# %%
w.count * 8
# Out:
# 528
