# %%
import anywidget
import traitlets

# %env ANYWIDGET_HMR=1

# %%
class CounterWidget(anywidget.AnyWidget):
    _esm = "./index.js"
    _css = ",.index.css"
    value = traitlets.Int(0).tag(sync=True)

CounterWidget()

# %%
CounterWidget.value
